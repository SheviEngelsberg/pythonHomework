# %%
pip install pandas
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB 1.4 MB/s eta 0:00:01
#      -------------------- ------------------- 30.7/61.0 kB 1.4 MB/s eta 0:00:01
#      ------------------------- ------------ 41.0/61.0 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 325.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 660.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.0/11.6 MB 660.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.0/11.6 MB 660.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.6 MB 393.8 kB/s eta 0:00:30
#    ---------------------------------------- 0.1/11.6 MB 595.3 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/11.6 MB 450.6 kB/s eta 0:00:26
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#
#   Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_1528\2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'כיתה': ['א', 'ב', 'ג'],
        'ממוצע ציונים': [99, 94, 88]}
sample = pd.DataFrame(data)
sample
# Out:
#        שם כיתה  ממוצע ציונים
# 0    אליז    א            99
# 1  בת שבע    ב            94
# 2    גליה    ג            88

# %%
sample.loc[len(sample.index)] = ['שדבי', 'ד', 93]  
sample
# Out:
#        שם כיתה  ממוצע ציונים
# 0    אליז    א            99
# 1  בת שבע    ב            94
# 2    גליה    ג            88
# 3      66   89            93
# 4      66   89            93
# 5    שדבי   89            93
# 6    שדבי    ד            93

# %%
sample['שם']
# Out:
# 0      אליז
# 1    בת שבע
# 2      גליה
# 3        66
# 4        66
# 5      שדבי
# 6      שדבי
# Name: שם, dtype: object

# %%
sample[sample['כיתה']=='א']
# Out:
#      שם כיתה  ממוצע ציונים
# 0  אליז    א            99

# %%
sample.describe().max()
# Out:
# ממוצע ציונים    99.0
# dtype: float64
